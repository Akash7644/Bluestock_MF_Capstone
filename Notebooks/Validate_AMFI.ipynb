# %%
import pandas as pd

# %%
fund_master= pd.read_csv(r"D:\Bluestock\Project\Data\Raw\01_fund_master.csv")
nav_hist= pd.read_csv(r"D:\Bluestock\Project\Data\Raw\02_nav_history.csv")

# %%
fund_master["amfi_code"].nunique()
# Out:
# 40

# %%
nav_hist["amfi_code"].nunique()
# Out:
# 40

# %%
missing_codes = set(fund_master["amfi_code"]) - set(nav_hist["amfi_code"])

print("Missing Codes:", missing_codes)
print("Count:", len(missing_codes))
# Out:
# Missing Codes: set()
# Count: 0

# %% [markdown]
# # AMFI Code Validation Report
#
# ## Objective
#
# Validate that all AMFI scheme codes present in the Fund Master dataset are available in the NAV History dataset.
#
# ## Validation Process
#
# - Extracted unique AMFI codes from `01_fund_master.csv`.
# - Extracted unique AMFI codes from `02_nav_history.csv`.
# - Compared both datasets using set difference to identify any missing scheme codes.
#
# ## Results
#
# - Total unique AMFI codes in Fund Master: **40**
# - Total unique AMFI codes in NAV History: **40**
# - Missing AMFI codes: **0**
#
# ## Data Quality Assessment
#
# - No missing AMFI codes were detected.
# - Every scheme present in the Fund Master dataset has corresponding NAV records in the NAV History dataset.
# - Referential integrity between the master dataset and NAV dataset is maintained.
#
# ## Conclusion
#
# The AMFI code validation was successful. All 40 schemes listed in the Fund Master dataset are represented in the NAV History dataset, confirming that the datasets are consistent and suitable for further ETL, analytics, and dashboard development.
